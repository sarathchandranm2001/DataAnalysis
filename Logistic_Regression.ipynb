# %% [markdown]
# <a href="https://colab.research.google.com/github/sarathchandranm2001/DataAnalysis/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import numpy as np               # For numerical computations
import pandas as pd              # For handling datasets
import matplotlib.pyplot as plt  # For plotting graphs
from sklearn.model_selection import train_test_split  # For splitting data into training and testing sets
from sklearn import datasets                          # To load a dataset
from sklearn.metrics import mean_squared_error, r2_score  # For evaluating the model
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Define the path to your dataset
file_path = '/content/drive/My Drive/Colab Notebooks/MCA306/DataSets/User_Data.csv'

# %%
# Load the dataset
data = pd.read_csv(file_path)

# Display the first few rows of the dataset to ensure it's loaded correctly
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
x = data.iloc[:, [2, 3]].values
y = data.iloc[:, 4].values
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.25, random_state = 0)
print('Feature Selection')
sc_x = StandardScaler()
xtrain = sc_x.fit_transform(xtrain)
xtest = sc_x.transform(xtest)
print (xtrain[0:10, :])
classifier = LogisticRegression(random_state = 0)
classifier.fit(xtrain, ytrain)
y_pred = classifier.predict(xtest)
print('Accuracy Score')
print(accuracy_score(ytest, y_pred))
# Out:
# Feature Selection
# [[ 0.58164944 -0.88670699]
#  [-0.60673761  1.46173768]
#  [-0.01254409 -0.5677824 ]
#  [-0.60673761  1.89663484]
#  [ 1.37390747 -1.40858358]
#  [ 1.47293972  0.99784738]
#  [ 0.08648817 -0.79972756]
#  [-0.01254409 -0.24885782]
#  [-0.21060859 -0.5677824 ]
#  [-0.21060859 -0.19087153]]
# Accuracy Score
# 0.89

# %% [markdown]
# **predict whether a user will purchase the company's product or not.**

# %%
# Create a new data point for prediction
new_data_point = [[30, 87000]]

# Scale the new data point using the same scaler used for training data
new_data_point_scaled = sc_x.transform(new_data_point)

# Predict the outcome for the new data point
prediction = classifier.predict(new_data_point_scaled)

# Print the prediction
print(f"Prediction for the new data point: {prediction}")

# Interpret the prediction
if prediction[0] == 1:
  print("The user is likely to purchase the product.")
else:
  print("The user is not likely to purchase the product.")
# Out:
# Prediction for the new data point: [0]
# The user is not likely to purchase the product.

# %% [markdown]
# # **Inferences**
#
# The model predicts whether a user will purchase a product based on age and estimated salary.
#
# The accuracy score indicates the model's performance in predicting the correct outcome.
#
# A higher accuracy score suggests a better model.
#
# The prediction for a new data point shows the model's ability to generalize to unseen data.
#
# The code demonstrates the process of data preprocessing, model training, and prediction using Logistic Regression.
#
# StandardScaler is used for feature scaling, which is important for improving model performance.
#
# The code showcases how to split data into training and testing sets for model evaluation.
#
# The model's prediction can be interpreted to understand the likelihood of a user purchasing the product.
